# %%
import pandas as pd
import requests
import json

# %%
url = "https://lab-ge.predix-uaa.run.aws-usw02-pr.ice.predix.io/oauth/token"

payload = "grant_type=client_credentials"
headers = {
    'authorization': "Basic dGltZXNlcmllcy1pbmdlc3Rpb24tc2VydmljZTp0aW1lc2VyaWVzLWluZ2VzdGlvbi1zZXJ2aWNl",
    'cache-control': "no-cache",
    'content-type': "application/x-www-form-urlencoded"
    }

response = requests.request("POST", url, data=payload, headers=headers)
token=json.loads(response.text)['access_token']
url = "https://time-series-store-predix.run.aws-usw02-pr.ice.predix.io/v1/datapoints"

payload = "{\n  \"start\": \"1y-ago\",\n  \"tags\": [\n    {\n      \"name\": \"place-de-la-nation-temperature\",\n      \"order\": \"desc\",\n      \"limit\": 80000\n    }\n  ]\n}"
headers = {
    'authorization': "Bearer " + token,
    'predix-zone-id': "bf0e82fd-0d9b-4d74-9c57-a612f21d449d",
    'content-type': "application/json",
    'cache-control': "no-cache"
    }

response = requests.request("POST", url, data=payload, headers=headers)
data=json.loads(response.text)['tags'][0]['results'][0]['values']
column_labels=['timestamp', 'values', 'quality']
series = pd.DataFrame(data, columns=column_labels)
# Out:
# {"tags":[{"name":"place-de-la-nation-temperature","results":[{"groups":[{"name":"type","type":"number"}],"values":[[1481759400000,48,3],[1481758800000,80,3],[1481758200000,5.30000019073,3],[1481757600000,80,3],[1481757000000,80,3],[1481756400000,72,3],[1481755800000,80,3],[1481755200000,80,3],[1481754600000,80,3],[1481754000000,80,3],[1481753400000,80,3],[1481752800000,80,3],[1481752200000,81,3],[1481751600000,90,3],[1481751000000,67,3],[1481750400000,77,3],[1481749800000,90,3],[1481749200000,90,3],[1481748600000,90,3],[1481748000000,90,3],[1481747400000,90,3],[1481746800000,90,3],[1481746200000,90,3],[1481745600000,70,3],[1481745000000,90,3],[1481744400000,90,3],[1481743800000,42,3],[1481743200000,100,3],[1481742600000,44,3],[1481742000000,90,3],[1481741400000,78,3],[1481740800000,100,3],[1481740200000,100,3],[1481739600000,100,3],[1481739000000,100,3],[1481738400000,100,3],[1481737800000,100,3],[1481737200000,102,3],[1481736600000,106,3],[1481736000000,110,3],[1481735400000,110,3],
# ...

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4d3f93ce-c5a4-451c-8600-dce135c51b0f">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(width=800, height=250, x_axis_type="datetime")
p.line(series['timestamp'], series['values'])
show(p)
# Out:
#     <div class="plotdiv" id="843fdcfd-2f9d-4ae2-b58a-9e9a22adec7d"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
# ...
